# %% [markdown]
# [IRkernel](https://github.com/IRkernel/IRkernel)

# %%
library(ggplot2)
options(jupyter.plot_mimetypes = "image/png")
options(repr.plot.width = 5, repr.plot.height = 5/1.61803398874989)

set.seed(123)

x <- rnorm(100)
y <- rchisq(100, df = 1, ncp = 0)
group <- sample(LETTERS[1:5], size = 100, replace = T)
size <- sample(1:5, size = 100, replace = T)

ds <- data.frame(x, y, group, size)

ggplot(data = ds) + geom_point(aes(x=x, y=y, size=size)) + facet_grid(. ~ group)

# %%
?ggplot
